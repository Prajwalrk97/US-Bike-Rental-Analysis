# %%
# !jt -t solarizedd -T -N -kl

# %%
# !jt -t monokai -f ptsans -fs 12 -nf ptsans -nfs 14 -T -N -kl

# %%
import jupyterthemes
# jtplot.style(theme='monokai', context='notebook', ticks=True, grid=False)

# %%
# !jt -t monokai -f fira -fs 14 -nf ptsans  -nfs 13 -N -kl -cursw 5 -cursc r -cellw 88% -T -N -kl

# %%
import seaborn as sns
tips = sns.load_dataset("tips")
sns.scatterplot(data=tips, x="total_bill", y="tip");

# %%
# !jt -t monokai -f fira -fs 14 -tfs 13 -nfs 13 -cellw 88% -T -N -kl
